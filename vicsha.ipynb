# %%
# !pip install pandas numpy matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (2.3.4)
# Requirement already satisfied: matplotlib in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\vicoa\anaconda3\envs\proyecto_final\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('Coffee Shop Sales.xlsx')

# %%
# Renombramos las columnas de nuestra data.
bd = data.rename(columns={
    'transaction_id': 'id de transaccion',
    'transaction_date': 'fecha de transaccion',
    'transaction_time': 'hora de transaccion',
    'transaction_qty': 'cantidad vendida',
    'store_id': 'id tienda',
    'store_location': 'ubicacion tienda',
    'product_id': 'id producto',
    'unit_price': 'precio unitario',
    'product_category': 'categoria producto',
    'product_type': 'tipo de producto',
    'product_detail': 'detalles del producto'
})

# Creamos la nueva columna de ingreso.
bd['total de ingresos'] = bd['cantidad vendida'] * bd['precio unitario']

#Convertimos la 'fecha_de_transaccion' a un datetime para evitar errores más adelante.
bd['fecha de transaccion'] = pd.to_datetime(bd['fecha de transaccion'])

# Creamos un diccionario en español para los meses abreviados.
meses_español_abr = {
    1: 'ENE', 2: 'FEB', 3: 'MAR', 4: 'ABR', 5: 'MAY', 6: 'JUN',
    7: 'JUL', 8: 'AGO', 9: 'SEP', 10: 'OCT', 11: 'NOV', 12: 'DIC'
}

# Usamos el diccionario para modificar nuestra columna.
bd['mes abreviado'] = bd['fecha de transaccion'].dt.month.map(meses_español_abr).apply(lambda x: f'MES {x}')

bd['hora de transaccion'] = pd.to_datetime(bd['fecha de transaccion'].astype(str) + ' ' + bd['hora de transaccion'].astype(str))

#Creamos la columna hora y convertimos su formato.
bd['hora'] = bd['hora de transaccion'].dt.hour

bd['turno'] = pd.cut(bd['hora'],
                     bins=[0, 12, 24],  # Mañana: 0-12, Tarde/Noche: 12-24
                     labels=["HORARIO DE LA MAÑANA", "HORARIO DE LA TARDE/NOCHE"],
                     right=False,
                     ordered=False)

display(bd.head())
# Out:
#    id de transaccion fecha de transaccion hora de transaccion  \
# 0                  1           2023-01-01 2023-01-01 07:06:11
# 1                  2           2023-01-01 2023-01-01 07:08:56
# 2                  3           2023-01-01 2023-01-01 07:14:04
# 3                  4           2023-01-01 2023-01-01 07:20:24
# 4                  5           2023-01-01 2023-01-01 07:22:41
#
#    cantidad vendida  id tienda ubicacion tienda  id producto  precio unitario  \
# 0                 2          5  Lower Manhattan           32              3.0
# 1                 2          5  Lower Manhattan           57              3.1
# 2                 2          5  Lower Manhattan           59              4.5
# 3                 1          5  Lower Manhattan           22              2.0
# 4                 2          5  Lower Manhattan           57              3.1
#
#    categoria producto       tipo de producto        detalles del producto  \
# 0              Coffee  Gourmet brewed coffee                  Ethiopia Rg
# 1                 Tea        Brewed Chai tea     Spicy Eye Opener Chai Lg
# 2  Drinking Chocolate          Hot chocolate            Dark chocolate Lg
# 3              Coffee            Drip coffee  Our Old Time Diner Blend Sm
# 4                 Tea        Brewed Chai tea     Spicy Eye Opener Chai Lg
#
#    total de ingresos mes abreviado  hora                 turno
# 0                6.0       MES ENE     7  HORARIO DE LA MAÑANA
# 1                6.2       MES ENE     7  HORARIO DE LA MAÑANA
# 2                9.0       MES ENE     7  HORARIO DE LA MAÑANA
# 3                2.0       MES ENE     7  HORARIO DE LA MAÑANA
# 4                6.2       MES ENE     7  HORARIO DE LA MAÑANA

# %%
print("Valores únicos en la columna 'turno':")
print(bd['turno'].unique())
print("\nFrecuencia de cada turno:")
print(bd['turno'].value_counts())
# Out:
# Valores únicos en la columna 'turno':
# ['HORARIO DE LA MAÑANA', 'HORARIO DE LA TARDE/NOCHE']
# Categories (2, object): ['HORARIO DE LA MAÑANA', 'HORARIO DE LA TARDE/NOCHE']
#
# Frecuencia de cada turno:
# turno
# HORARIO DE LA MAÑANA         81751
# HORARIO DE LA TARDE/NOCHE    67365
# Name: count, dtype: int64

# %%
bd.info() #Evaluamos la nueva estructura de los datos de nuestro dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id de transaccion      149116 non-null  int64
#  1   fecha de transaccion   149116 non-null  datetime64[ns]
#  2   hora de transaccion    149116 non-null  datetime64[ns]
#  3   cantidad vendida       149116 non-null  int64
#  4   id tienda              149116 non-null  int64
#  5   ubicacion tienda       149116 non-null  object
#  6   id producto            149116 non-null  int64
#  7   precio unitario        149116 non-null  float64
#  8   categoria producto     149116 non-null  object
#  9   tipo de producto       149116 non-null  object
#  10  detalles del producto  149116 non-null  object
#  11  total de ingresos      149116 non-null  float64
#  12  mes abreviado          149116 non-null  object
#  13  hora                   149116 non-null  int32
#  14  turno                  149116 non-null  category
# dtypes: category(1), datetime64[ns](2), float64(2), int32(1), int64(4), object(5)
# memory usage: 15.5+ MB

# %%
# Desarrollamos la función para crear las estadísticas descriptivas condicionadas al ingreso.
def analizar_estadisticas(df, group_col):
    """
    Calcula estadísticas descriptivas para total_ingresos agrupados por una columna.

    Args:
        df: El DataFrame de entrada.
        group_col: La columna por la cual agrupar.

    Returns:
        Un DataFrame con estadísticas descriptivas.
    """
    if group_col not in df.columns:
        raise ValueError(f"Grouping column '{group_col}' not found in DataFrame.")

    # Calculamos las estadísticas descriptivas.
    resultado = df.groupby(group_col, observed=True).agg(
        transacciones=('id de transaccion', 'count'),
        ingreso_total=('total de ingresos', 'sum'),
        ingreso_minimo=('total de ingresos', 'min'),
        ingreso_maximo=('total de ingresos', 'max'),
        ingreso_promedio=('total de ingresos', 'mean'),
        ingreso_mediano=('total de ingresos', 'median'),
        desviacion_ingresos=('total de ingresos', 'std'),
        q1_ingresos=('total de ingresos', lambda x: x.quantile(0.25)),
        q3_ingresos=('total de ingresos', lambda x: x.quantile(0.75))
    )

    # Calculamos estadísticas adicionales.
    resultado['rango de ingresos'] = resultado['ingreso_maximo'] - resultado['ingreso_minimo']
    resultado['desviacion_mediana'] = df.groupby(group_col, observed=True)['total de ingresos'].apply(lambda x: np.sqrt(np.mean((x - np.median(x))**2)))

    # Coeficiente de variación
    resultado['CV % ingresos'] = (resultado['desviacion_ingresos'] / resultado['ingreso_promedio']) * 100

    # Redondeamos los valores a 2 decimales.
    resultado = resultado.round(2)

    return resultado

# %%
analisis_por_mes_abreviado = analizar_estadisticas(bd, 'mes abreviado')
meses_ordenados = ['MES ENE', 'MES FEB', 'MES MAR', 'MES ABR', 'MES MAY', 'MES JUN']
analisis_por_mes_abreviado = analisis_por_mes_abreviado.reindex(meses_ordenados)

display(analisis_por_mes_abreviado)
# Out:
#                transacciones  ingreso_total  ingreso_minimo  ingreso_maximo  \
# mes abreviado
# MES ENE                17314       81677.74             0.8           360.0
# MES FEB                16359       76145.19             0.8            45.0
# MES MAR                21229       98834.68             0.8            72.0
# MES ABR                25335      118941.08             0.8           360.0
# MES MAY                33527      156727.76             0.8           360.0
# MES JUN                35352      166485.88             0.8           360.0
#
#                ingreso_promedio  ingreso_mediano  desviacion_ingresos  \
# mes abreviado
# MES ENE                    4.72             3.75                 4.95
# MES FEB                    4.65             3.75                 3.02
# MES MAR                    4.66             3.75                 3.08
# MES ABR                    4.69             3.75                 4.39
# MES MAY                    4.67             3.75                 4.08
# MES JUN                    4.71             3.75                 4.89
#
#                q1_ingresos  q3_ingresos  rango de ingresos  \
# mes abreviado
# MES ENE                3.0          6.0              359.2
# MES FEB                3.0          6.0               44.2
# MES MAR                3.0          6.0               71.2
# MES ABR                3.0          6.0              359.2
# MES MAY                3.0          6.0              359.2
# MES JUN                3.0          6.0              359.2
#
#                desviacion_mediana  CV % ingresos
# mes abreviado
# MES ENE                      5.05         104.99
# MES FEB                      3.15          64.90
# MES MAR                      3.21          66.14
# MES ABR                      4.49          93.41
# MES MAY                      4.18          87.26
# MES JUN                      4.98         103.75

# %%
analisis_por_ubicacion = analizar_estadisticas(bd, 'ubicacion tienda')
display(analisis_por_ubicacion)
# Out:
#                   transacciones  ingreso_total  ingreso_minimo  \
# ubicacion tienda
# Astoria                   50599      232243.91             0.8
# Hell's Kitchen            50735      236511.17             0.8
# Lower Manhattan           47782      230057.25             0.8
#
#                   ingreso_maximo  ingreso_promedio  ingreso_mediano  \
# ubicacion tienda
# Astoria                     45.0              4.59             3.75
# Hell's Kitchen             360.0              4.66             3.75
# Lower Manhattan             72.0              4.81             3.75
#
#                   desviacion_ingresos  q1_ingresos  q3_ingresos  \
# ubicacion tienda
# Astoria                          2.88          3.0          6.0
# Hell's Kitchen                   5.84          3.0          6.0
# Lower Manhattan                  3.28          3.0          6.0
#
#                   rango de ingresos  desviacion_mediana  CV % ingresos
# ubicacion tienda
# Astoria                        44.2                3.00          62.69
# Hell's Kitchen                359.2                5.91         125.26
# Lower Manhattan                71.2                3.45          68.14

# %%
analisis_por_turno = analizar_estadisticas(bd, 'turno')
display(analisis_por_turno)
# Out:
#                            transacciones  ingreso_total  ingreso_minimo  \
# turno
# HORARIO DE LA MAÑANA               81751      388288.67             0.8
# HORARIO DE LA TARDE/NOCHE          67365      310523.66             0.8
#
#                            ingreso_maximo  ingreso_promedio  ingreso_mediano  \
# turno
# HORARIO DE LA MAÑANA                360.0              4.75             3.75
# HORARIO DE LA TARDE/NOCHE            45.0              4.61             3.75
#
#                            desviacion_ingresos  q1_ingresos  q3_ingresos  \
# turno
# HORARIO DE LA MAÑANA                      5.13          3.0          6.0
# HORARIO DE LA TARDE/NOCHE                 2.76          3.0          6.0
#
#                            rango de ingresos  desviacion_mediana  \
# turno
# HORARIO DE LA MAÑANA                   359.2                5.22
# HORARIO DE LA TARDE/NOCHE               44.2                2.89
#
#                            CV % ingresos
# turno
# HORARIO DE LA MAÑANA              107.96
# HORARIO DE LA TARDE/NOCHE          59.94

# %%
analisis_por_categoria = analizar_estadisticas(bd, 'categoria producto')
display(analisis_por_categoria)
# Out:
#                     transacciones  ingreso_total  ingreso_minimo  \
# categoria producto
# Bakery                      22796       82315.64            2.65
# Branded                       747       13607.00           12.00
# Coffee                      58416      269952.45            2.00
# Coffee beans                 1753       40085.25           10.00
# Drinking Chocolate          11468       72416.00            3.50
# Flavours                     6790        8408.80            0.80
# Loose Tea                    1210       11213.60            8.95
# Packaged Chocolate            487        4407.64            6.40
# Tea                         45449      196405.95            2.50
#
#                     ingreso_maximo  ingreso_promedio  ingreso_mediano  \
# categoria producto
# Bakery                        9.00              3.61             3.50
# Branded                      72.00             18.22            14.00
# Coffee                       17.00              4.62             4.20
# Coffee beans                360.00             22.87            19.75
# Drinking Chocolate           14.25              6.31             7.00
# Flavours                      3.20              1.24             1.60
# Loose Tea                    10.95              9.27             8.95
# Packaged Chocolate           13.33              9.05             7.60
# Tea                          12.00              4.32             5.00
#
#                     desviacion_ingresos  q1_ingresos  q3_ingresos  \
# categoria producto
# Bakery                             0.58         3.25         3.75
# Branded                            7.90        12.00        28.00
# Coffee                             2.00         3.00         6.00
# Coffee beans                      27.05        15.00        21.00
# Drinking Chocolate                 2.39         4.50         9.00
# Flavours                           0.44         0.80         1.60
# Loose Tea                          0.60         8.95         9.25
# Packaged Chocolate                 2.87         7.60        13.33
# Tea                                1.68         2.55         6.00
#
#                     rango de ingresos  desviacion_mediana  CV % ingresos
# categoria producto
# Bakery                           6.35                0.59          16.10
# Branded                         60.00                8.95          43.35
# Coffee                          15.00                2.05          43.36
# Coffee beans                   350.00               27.22         118.28
# Drinking Chocolate              10.75                2.48          37.80
# Flavours                         2.40                0.57          35.13
# Loose Tea                        2.00                0.68           6.44
# Packaged Chocolate               6.93                3.21          31.72
# Tea                              9.50                1.81          38.90
